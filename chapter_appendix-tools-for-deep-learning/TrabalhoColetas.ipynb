# %% [markdown]
# # Trabalho-Coletas

# %% [markdown]
#  Instalar bibliotecas necessárias

# %%
pip install requests beautifulsoup4 pandas lxml
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Importar bibliotecas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %% [markdown]
# Fazer requisição da página

# %%
url = "https://pt.wikipedia.org/wiki/Bad_Bunny"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    print("Página acessada")
else:
    print("Erro ao acessar a página")
# Out:
# Página acessada

# %% [markdown]
# Criar o objeto BeautifulSoup

# %%
soup = BeautifulSoup(response.content, "lxml")

# %% [markdown]
# Extrair informações principais
# Titulo

# %%
titulo = soup.find("h1").text
print(titulo)
# Out:
# Bad Bunny

# %% [markdown]
# Primeiro paragrafo

# %%
primeiro_paragrafo = soup.find("p").text
print(primeiro_paragrafo)
# Out:
# Benito Antonio Martinez Ocasio (10 de março de 1994)[3][4], conhecido profissionalmente como Bad Bunny, é um rapper, cantor, produtor musical, ator e ocasionalmente lutador profissional porto-riquenho.[5]

# %% [markdown]
# Tabela lateral

# %%
infobox = soup.find("table", class_="infobox")

dados_infobox = {}

for linha in infobox.find_all("tr"):
    if linha.th and linha.td:
        chave = linha.th.text.strip()
        valor = linha.td.text.strip()
        dados_infobox[chave] = valor

print(dados_infobox)
# Out:
# {'Nome completo': 'Benito Antonio Martinez Ocasio', 'Pseudônimo(s)': 'Rei do trap latino', 'Nascimento': '10 de março de 1994\xa0(32\xa0anos)Bayamon, Porto Rico', 'Nacionalidade': 'porto-riquenho[a]', 'Ocupação': 'Rapper\ncantor\ncompositor\nprodutor musical\nator\nlutador', 'Prêmios': 'Lista completa', 'Período musical': '2013–presente', 'Gênero(s)': 'Trap latino\nreggaeton', 'Extensão vocal': 'Barítono', 'Instrumento(s)': 'Vocais', 'Gravadora(s)': 'Rimas\nHear this Music', 'Religião': 'catolicismo', 'Website': 'debitirarmasfotos.com'}

# %% [markdown]
# Extrair links internos da página

# %%
links = []

for link in soup.find_all("a"):
    href = link.get("href")
    if href and href.startswith("/wiki/") and ":" not in href:
        links.append("https://pt.wikipedia.org" + href)

links_unicos = list(set(links))

print(f"Total de links internos: {len(links_unicos)}")
print(links_unicos[:10])
# Out:
# Total de links internos: 1
# ['https://pt.wikipedia.org/wiki/Bad_Bunny']

# %% [markdown]
# Salvar os dados

# %%
df_links = pd.DataFrame(links_unicos, columns=["Link"])
df_links.to_csv("links_bad_bunny.csv", index=False)
